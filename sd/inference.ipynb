# %%
import model_loader
import pipeline
from PIL import Image
from pathlib import Path
from transformers import CLIPTokenizer
import torch

DEVICE = "cpu"

ALLOW_CUDA = False
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"

print(f"Using device : {DEVICE}")

tokenizer = CLIPTokenizer("../data/vocab.json", merges_file="../data/merges.txt")
model_file = "../data/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)

# TEXT TO IMAGE

prompt = "A dog running in park, ultra sharp, cinematic, 8k resolution"
uncond_prompt = "" # use it for negative prompting
do_cfg = True
cfg_scale = 7

# IMAGE TO IMAGE
input_image = None
image_path = "../images/dog.jpg"
#input_image = Image.open(image_path)
strength = 0.9

sampler = "ddpm"
num_imference_steps = 50
seed = 42

output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=input_image,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_imference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer
)

Image.fromarray(output_image)
# Out:
# Using device : cpu
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 20
#      18 tokenizer = CLIPTokenizer("../data/vocab.json", merges_file="../data/merges.txt")
#      19 model_file = "../data/v1-5-pruned-emaonly.ckpt"
# ---> 20 models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)
#      22 # TEXT TO IMAGE
#      24 prompt = "add Eiffel Tower in backgroud, highly detailed, ultra sharp, cinematic, 8k resolution"
#
# File c:\Users\AKASH\stable-diffusion\sd\model_loader.py:9, in preload_models_from_standard_weights(ckpt_path, device)
#       8 def preload_models_from_standard_weights(ckpt_path, device):
# ----> 9     state_dict = model_converter.load_from_standard_weights(ckpt_path, device)
#      11     encoder = VAE_Encoder().to(device)
#      12     encoder.load_state_dict(state_dict['encoder'], strict=True)
#
# File c:\Users\AKASH\stable-diffusion\sd\model_converter.py:5, in load_from_standard_weights(input_file, device)
#       3 def load_from_standard_weights(input_file: str, device: str) -> dict[str, torch.Tensor]:
#       4     # Taken from: https://github.com/kjsman/stable-diffusion-pytorch/issues/7#issuecomment-1426839447
# ----> 5     original_model = torch.load(input_file, map_location=device, weights_only = False)["state_dict"]
#       7     converted = {}
#       8     converted['diffusion'] = {}
#
# File c:\Users\AKASH\stable-diffusion\venv\Lib\site-packages\torch\serialization.py:1360, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1358             except pickle.UnpicklingError as e:
#    1359                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1360         return _load(
#    1361             opened_zipfile,
#    1362             map_location,
#    1363             pickle_module,
#    1364             overall_storage=overall_storage,
#    1365             **pickle_load_args,
#    1366         )
#    1367 if mmap:
#    1368     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File c:\Users\AKASH\stable-diffusion\venv\Lib\site-packages\torch\serialization.py:1848, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1846 global _serialization_tls
#    1847 _serialization_tls.map_location = map_location
# -> 1848 result = unpickler.load()
#    1849 _serialization_tls.map_location = None
#    1851 torch._utils._validate_loaded_sparse_tensors()
#
# File c:\Users\AKASH\stable-diffusion\venv\Lib\site-packages\torch\serialization.py:1812, in _load.<locals>.persistent_load(saved_id)
#    1810 else:
#    1811     nbytes = numel * torch._utils._element_size(dtype)
# -> 1812     typed_storage = load_tensor(
#    1813         dtype, nbytes, key, _maybe_decode_ascii(location)
#    1814     )
#    1816 return typed_storage
#
# File c:\Users\AKASH\stable-diffusion\venv\Lib\site-packages\torch\serialization.py:1772, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    1769     storage = overall_storage[storage_offset : storage_offset + numel]
#    1770 else:
#    1771     storage = (
# -> 1772         zip_file.get_storage_from_record(name, numel, torch.UntypedStorage)
#    1773         ._typed_storage()
#    1774         ._untyped_storage
#    1775     )
#    1776 # swap here if byteswapping is needed
#    1777 if byteorderdata is not None:
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 409600 bytes.
